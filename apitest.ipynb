# %%
from google import genai
from google.genai import types

with open('/workspace/SAM3RAG/assets/cracks/GAPS384_train_0541_1_641.jpg', 'rb') as f:
      image_bytes = f.read()

GEMINI_API_KEY="AIzaSyBcNJQXVjgj-XRqgzfxO-gxdb38y7dkuaA"
client = genai.Client(api_key=GEMINI_API_KEY)

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents=[
      types.Part.from_bytes(
        data=image_bytes,
        mime_type='image/jpeg',
      ),
      'can you see crack in this image? and explain where is the crack located and its material'
    ]
)
print(response.text)
# Out:
# Yes, I can see a crack in the image.
#
# **Location:** The crack is located in the **right half** of the image, extending diagonally from the top right towards the bottom left. It's most prominent in the upper right quadrant and continues down into the lower right quadrant.
#
# **Material:** The crack appears to be in **asphalt**. The texture of the image, with its small, embedded stones and granular appearance, is characteristic of asphalt pavement. The crack itself is a dark line within this material, indicating a fracture in the asphalt surface.
